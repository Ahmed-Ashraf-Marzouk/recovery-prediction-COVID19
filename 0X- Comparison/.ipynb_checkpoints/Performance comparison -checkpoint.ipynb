# %% [markdown]
# # KNN

# %%
# %run "KNN Classifier.ipynb"
# Out:
# Number of rows: 863
# Number of cases with first value: 862
# Number of cases with Second value: 1
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       150
#            1       0.86      0.78      0.82        23
#
#     accuracy                           0.95       173
#    macro avg       0.91      0.88      0.90       173
# weighted avg       0.95      0.95      0.95       173

# %% [markdown]
# # Logistic regression

# %%
# %run "Logistic Regressionm.ipynb"
# Out:
# 82.5
# 14.5
# 863
# Total number of age outliers removed: 27
# 836
# GridSearchCV(estimator=LogisticRegression(max_iter=10000, multi_class='ovr',
#                                           solver='saga'),
#              param_grid={'C': array([1.00000000e+00, 2.78255940e+00, 7.74263683e+00, 2.15443469e+01,
#        5.99484250e+01, 1.66810054e+02, 4.64158883e+02, 1.29154967e+03,
#        3.59381366e+03, 1.00000000e+04]),
#                          'penalty': ['l1', 'l2']})
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       149
#            1       0.81      0.89      0.85        19
#
#     accuracy                           0.96       168
#    macro avg       0.90      0.93      0.91       168
# weighted avg       0.97      0.96      0.97       168

# %% [markdown]
# # Naive Bayes

# %%
# %run "Naive_Bayes.ipynb"
# Out:
# Let's get started! 🚀
# 82.5
# 14.5
# 863
# Total number of age outliers removed: 27
# 836
# Number of rows: 836
# Number of cases with first value: 835
# Number of cases with Second value: 1
# Useless variable 💥
# 836
# 834
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94        59
#            1       0.50      0.12      0.20         8
#
#     accuracy                           0.88        67
#    macro avg       0.70      0.55      0.57        67
# weighted avg       0.85      0.88      0.85        67
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92        59
#            1       0.33      0.25      0.29         8
#
#     accuracy                           0.85        67
#    macro avg       0.62      0.59      0.60        67
# weighted avg       0.83      0.85      0.84        67
#
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# From previous figures we can conclude that:
# Logistic regression performed well because we work mostly on categrical variables.
# For naive bayes performance was approximatly the same as the logistic regression in performance as we see from the figure above most of the variables are independent, which supports the theory of naive bayes.
# For knn it was not easy to learn from the categorical data as we have only two continous variables!
